# %% [markdown]
# # QUASAR synthetic validation
# Run the registered experiments from a notebook. Install the package with `python -m pip install -e .` first.

# %%
from quasar_engine.experiment import run_domain

fraud = run_domain('fraud', points=360, seed=42)
astronomy = run_domain('astronomy', points=360, seed=42)
{name: result['metrics']['calibrated_test'] for name, result in {'fraud': fraud, 'astronomy': astronomy}.items()}
