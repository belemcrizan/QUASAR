# %% [markdown]
# # Fraud/surveillance exploration
# Inspect synthetic inputs before running the core. These records do not model a real institution.

# %%
from quasar_engine.adapters.fraud import FraudAdapter, generate_synthetic_fraud
records = generate_synthetic_fraud(points=360, seed=42)
observations = FraudAdapter().adapt_many(records)
observations[:2]
