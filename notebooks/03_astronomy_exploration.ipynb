# %% [markdown]
# # Astronomy exploration
# Inspect telescope-like synthetic inputs. No real astronomical discovery is claimed.

# %%
from quasar_engine.adapters.astronomy import AstronomyAdapter, generate_synthetic_astronomy
records = generate_synthetic_astronomy(points=360, seed=42)
observations = AstronomyAdapter().adapt_many(records)
observations[:2]
